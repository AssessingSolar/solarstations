# %% [markdown]
# # Station listing
#
# Ground measured solar irradiance data is extremely valuable and critical for benchmarking solar radiation products and understanding long-term trends in the radiation budget. However, due to high costs and maintenance requirements, there are only a few hundred high-quality stations globally. This catalog provides an overview of available solar radiation monitoring stations worldwide and supporting metadata.
#
# The current version of this catalog is in a draft phase, where only the BSRN stations are included as a demonstration.

# %%
import pandas as pd

stations = pd.read_csv('solarstations.csv', sep=';', encoding='latin1')
stations.head()
# Out:
#   Station full name Abbreviation               State    Country  Latitude  \
# 0          Abashiri          ABS                 NaN      Japan   44.0178
# 1             Alert          ALE         Lincoln Sea     Canada   82.4900
# 2     Alice Springs          ASP  Northern Territory  Australia  -23.7980
# 3            Barrow          BAR              Alaska        USA   71.3230
# 4           Bermuda          BER             Bermuda        USA   32.2670
#
#    Longitude  Elevation Time period Network                     Comment  URL  \
# 0   144.2797       38.0       2021-    BSRN  Candidate station (no. 86)  NaN
# 1   -62.4200      127.0   2004-2014    BSRN                         NaN  NaN
# 2   133.8880      547.0       1995-    BSRN                         NaN  NaN
# 3  -156.6070        8.0       1992-    BSRN                         NaN  NaN
# 4   -64.6670        8.0       1992-    BSRN                         NaN  NaN
#
#    Tier 2  Instrument
# 0       1  Thermopile
# 1       1  Thermopile
# 2       1  Thermopile
# 3       1  Thermopile
# 4       1  Thermopile

# %%
from itables import init_notebook_mode
init_notebook_mode(all_interactive=True)
stations
# Out:
#    Station full name Abbreviation               State    Country  Latitude  \
# 0           Abashiri          ABS                 NaN      Japan   44.0178
# 1              Alert          ALE         Lincoln Sea     Canada   82.4900
# 2      Alice Springs          ASP  Northern Territory  Australia  -23.7980
# 3             Barrow          BAR              Alaska        USA   71.3230
# 4            Bermuda          BER             Bermuda        USA   32.2670
# ..               ...          ...                 ...        ...       ...
# 80          Portland          NaN              Oregon        USA   45.5100
# 81             Burns          NaN              Oregon        USA   43.5200
# 82       Silver lake          NaN              Oregon        USA   43.1200
# 83           Ashland          NaN              Oregon        USA   42.1900
# 84           Seattle          NaN          Washington        USA   47.6540
#
#     Longitude  Elevation Time period Network  \
# 0    144.2797       38.0       2021-    BSRN
# 1    -62.4200      127.0   2004-2014    BSRN
# 2    133.8880      547.0       1995-    BSRN
# 3   -156.6070        8.0       1992-    BSRN
# 4    -64.6670        8.0       1992-    BSRN
# ..        ...        ...         ...     ...
# 80  -122.6900       70.0       2011-    SRML
# 81   119.0200     1265.0       2011-    SRML
# 82  -121.0600     1355.0       2002-    SRML
# 83  -122.7000      595.0       2018-    SRML
# 84  -122.3090       70.0       2015-    SRML
#
#                               Comment  \
# 0          Candidate station (no. 86)
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 80  5-min data between 2004 and 2011.
# 81      5 min data from 1994 to 2011.
# 82                Only 5 minute data?
# 83   5-minute data from 2000 to 2018.
# 84                                NaN
#
#                                             URL  Tier 2  Instrument
# 0                                           NaN       1  Thermopile
# 1                                           NaN       1  Thermopile
# 2                                           NaN       1  Thermopile
# 3                                           NaN       1  Thermopile
# 4                                           NaN       1  Thermopile
# ..                                          ...     ...         ...
# 80  http://solardat.uoregon.edu/PortlandPV.html       2         RSR
# 81       http://solardat.uoregon.edu/Burns.html       1  Thermopile
# 82  http://solardat.uoregon.edu/SilverLake.html       2         RSP
# 83     http://solardat.uoregon.edu/Ashland.html       2         RSP
# 84  http://solardat.uoregon.edu/Seattle_UW.html       1  Thermopile
#
# [85 rows x 13 columns]

# %% [markdown]
# ## Improvements
# The table of stations above will be made sortable and with clickable url's.
