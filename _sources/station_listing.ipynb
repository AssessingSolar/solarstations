# %% [markdown]
# # Station listing
#
# This site provides an overview of available solar radiation monitoring stations worldwide and metadata of the stations.
#
# The current version of this catalog is in a draft phase, so many stations are not yet shown. A searchable version of the table below is available [here](https://github.com/AssessingSolar/solarstations/blob/main/test.csv).

# %%
import pandas as pd
from itables import init_notebook_mode, show

init_notebook_mode(all_interactive=True)

stations = pd.read_csv('solarstations.csv', encoding='latin1').fillna('')

show(stations, paging=False)  #
# Out:
# <table id="d646d2ca-d5f5-4cd0-b177-8bb66b7fe8f3" class="display"style="max-width:100%"><thead><th>Station full name</th><th>Abbreviation</th><th>State</th><th>Country</th><th>Latitude</th><th>Longitude</th><th>Elevation</th><th>Time period</th><th>Network</th><th>Owner</th><th>Comment</th><th>URL</th><th>Data availability</th><th>Tier</th><th>Instrument</th><th>Components</th></thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.11.3/css/jquery.dataTables.min.css">
# <style> table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <style> table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <script type="module">
#     // Define the table data
#     const data = [["Abashiri", "ABS", "", "Japan", 44.0178, 144.2797, "38.0", "2021-", "BSRN", "", "Candidate station (no. 86)", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Alert", "ALE", "Lincoln Sea", "Canada", 82.49, -62.42, "127.0", "2004-2014", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Alice Springs", "ASP", "Northern Territory", "Australia", -23.798, 133.888, "547.0", "1995-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Barrow", "BAR", "Alaska", "USA", 71.323, -156.607, "8.0", "1992-", "BSRN; ABO", "NOAA", "", "https://gml.noaa.gov/obop/brw/", "Freely", "1.0", "Thermopile", "G;B;D"], ["Bermuda", "BER", "Bermuda", "USA", 32.267, -64.667, "8.0", "1992-2013& 2016-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Billings", "BIL", "Oklahoma", "USA", 36.605, -97.516, "317.0", "1993-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Bondville", "BON", "Illinois", "USA", 40.0667, -88.3667, "213.0", "1995-", "BSRN; SURFRAD", "NOAA", "", "http://www.srrb.noaa.gov/surfrad/bondvill.html", "Freely", "1.0", "Thermopile", "G;B;D"], ["Boulder", "BOS", "Colorado", "USA", 40.125, -105.237, "1689.0", "1995-", "BSRN; SURFRAD", "NOAA", "", "https://gml.noaa.gov/grad/surfrad/tablemt.html", "Freely", "1.0", "Thermopile", "G;B;D"], ["Boulder", "BOU", "Colorado", "USA", 40.05, -105.007, "1577.0", "1992-2016", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Brasilia", "BRB", "Brasilia City", "Brazil", -15.601, -47.713, "1023.0", "2006-2015&2018-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Budapest-Lorinc", "BUD", "Budapest", "Hungary", 47.4291, 19.1822, "139.1", "2019-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Cabauw", "CAB", "", "Netherlands", 51.9711, 4.9267, "0.0", "2005-", "BSRN", "", "", "https://dataplatform.knmi.nl/dataset/cesar-bsrn-irraddown-la1-t1-v1-0", "Freely", "1.0", "Thermopile", "G;B;D"], ["Camborne", "CAM", "", "United Kingdom", 50.2167, -5.3167, "88.0", "2001-", "BSRN", "", "", "https://epic.awi.de/id/eprint/40425/1/Camborne_BSRN_Station_Info.pdf", "Freely", "1.0", "Thermopile", "G;B;D"], ["Cape Baranova", "CAP", "", "Russia", 79.27, 101.75, "", "2016-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Carpentras", "CAR", "", "France", 44.083, 5.059, "100.0", "1996-2018", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Chesapeake Light", "CLH", "North Atlantic Ocean", "USA", 36.905, -75.713, "37.0", "2000-2016", "BSRN", "NASA", "Closed due to structural issues", "https://science.larc.nasa.gov/crave/", "Freely", "1.0", "Thermopile", "G;B;D"], ["Cener", "CNR", "Navarra", "Spain", 42.816, -1.601, "471.0", "2009-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Cocos Island", "COC", "Cocos (Keeling) Islands", "Australia", -12.193, 96.835, "6.0", "2004-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["De Aar", "DAA", "", "South Africa", -30.6667, 23.993, "1287.0", "2000-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Darwin", "DAR", "", "Australia", -12.425, 130.891, "30.0", "2002-2015", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Concordia Station& Dome C", "DOM", "", "Antarctica", -75.1, 123.383, "3233.0", "2006", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Dongsha Atoll", "DON", "", "Taiwan", 20.7, 116.73, "2.0", "", "BSRN", "", "Candidate", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Desert Rock", "DRA", "Nevada", "USA", 36.626, -116.018, "1007.0", "1994-", "BSRN; SURFRAD", "NOAA", "", "https://gml.noaa.gov/grad/surfrad/desrock.html", "Freely", "1.0", "Thermopile", "G;B;D"], ["Darwin Met Office", "DWN", "", "Australia", -12.424, 130.8925, "32.0", "2008-", "BSRN", "", "", "", "Freely", "1.0", "Thermopile", "G;B;D"], ["Southern Great Plains", "E13", "Oklahoma", "USA", 36.605, -97.485, "318.0", "1994-", "BSRN; ARM", "", "", "http://www.arm.gov/sites/sgp", "Freely", "1.0", "Thermopile ...
